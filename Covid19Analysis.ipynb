# %%
# Importing libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
# Reading dataset

# %%
df
# Loading dataset
# Out:
#     sno                                state_name  active  positive     cured  \
# 0     1               Andaman and Nicobar Islands       3     10039      9907
# 1     2                            Andhra Pradesh      72   2319797   2304995
# 2     3                         Arunachal Pradesh       4     64503     64203
# 3     4                                     Assam       2    724220    716232
# 4     5                                     Bihar      49    830653    818348
# 5     6                                Chandigarh      84     92208     90959
# 6     7                              Chhattisgarh      28   1152333   1138271
# 7     8  Dadra and Nagar Haveli and Daman and Diu       0     11441     11437
# 8     9                                     Delhi    4341   1899072   1868543
# 9    10                                       Goa      67    245548    241649
# 10   11                                   Gujarat     211   1224657   1213502
# 11   12                                   Haryana    1935    998552    985996
# 12   13                          Himachal Pradesh      69    284926    280721
# 13   14                         Jammu and Kashmir      55    454131    449325
# 14   15                                 Jharkhand      38    435289    429933
# 15   16                                 Karnataka    1861   3949446   3907480
# 16   17                                 Kerala***    3323   6546235   6473557
# 17   18                                    Ladakh       9     28256     28019
# 18   19                               Lakshadweep       0     11402     11350
# 19   20                            Madhya Pradesh     232   1041867   1030900
# 20   21                               Maharashtra    1455   7880337   7731029
# 21   22                                   Manipur       8    137230    135102
# 22   23                                 Meghalaya      13     93819     92213
# 23   24                                   Mizoram     260    227962    227005
# 24   25                                  Nagaland       1     35492     34731
# 25   26                                    Odisha     166   1288272   1278980
# 26   27                                Puducherry      12    165806    163832
# 27   28                                    Punjab     170    760028    742107
# 28   29                                 Rajasthan     616   1284618   1274448
# 29   30                                    Sikkim       7     39161     38702
# 30   31                                Tamil Nadu     424   3454556   3416107
# 31   32                                 Telangana     418    792526    787997
# 32   33                                   Tripura       1    100887     99963
# 33   34                               Uttarakhand     477    437674    429504
# 34   35                             Uttar Pradesh    1278   2077406   2052615
# 35   36                               West Bengal     407   2018763   1997153
# 36   37                                             18096  43119112  42576815
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129           3         10039       9907        129
# 1    14730          79       2319814    2305005      14730
# 2      296           4         64503      64203        296
# 3     7986           2        724220     716232       7986
# 4    12256          38        830659     818365      12256
# 5     1165          90         92226      90971       1165
# 6    14034          28       1152334    1138272      14034
# 7        4           0         11441      11437          4
# 8    26188        3936       1899745    1869617      26192
# 9     3832          77        245562     241653       3832
# 10   10944         218       1224688    1213526      10944
# 11   10621        1952        998895     986322      10621
# 12    4136          78        284938     280724       4136
# 13    4751          58        454139     449330       4751
# 14    5318          34        435293     429941       5318
# 15   40105        1868       3949549    3907576      40105
# 16   69363        3393       6546758    6474002      69363                8
# 17     228           8         28256      28020        228
# 18      52           0         11402      11350         52
# 19   10735         244       1041903    1030924      10735
# 20  147853        1439       7880585    7731292     147854
# 21    2120           8        137230     135102       2120
# 22    1593          13         93820      92214       1593
# 23     697         269        227992     227026        697
# 24     760           2         35493      34731        760
# 25    9126         184       1288290    1278980       9126
# 26    1962          12        165809     163835       1962
# 27   17751         165        760051     742135      17751
# 28    9554         558       1284673    1274561       9554
# 29     452           7         39161      38702        452
# 30   38025         408       3454591    3416158      38025
# 31    4111         424        792571     788036       4111
# 32     923           1        100887      99963        923
# 33    7693         497        437698     429508       7693
# 34   23513        1174       2077564    2052877      23513
# 35   21203         421       2018820    1997196      21203
# 36  524201       17692      43121599   42579693     524214                8
#
#    total  state_code
# 0                 35
# 1                 28
# 2                 12
# 3                 18
# 4                 10
# 5                  4
# 6                 22
# 7                 26
# 8      4           7
# 9                 30
# 10                24
# 11                 6
# 12                 2
# 13                 1
# 14                20
# 15                29
# 16     8          32
# 17                37
# 18                31
# 19                23
# 20     1          27
# 21                14
# 22                17
# 23                15
# 24                13
# 25                21
# 26                34
# 27                 3
# 28                 8
# 29                11
# 30                33
# 31                36
# 32                16
# 33                 5
# 34                 9
# 35                19
# 36    13           0

# %% [markdown]
# ### DataUnderstanding

# %%
df.shape
# There are 37 rows and 11 columns
# Out:
# (37, 13)

# %%
df.isnull().sum()
# no null values
# Out:
# sno                 0
# state_name          0
# active              0
# positive            0
# cured               0
# death               0
# new_active          0
# new_positive        0
# new_cured           0
# new_death           0
# death_reconsille    0
# total               0
# state_code          0
# dtype: int64

# %%
df.info()
# type of data present in the columns(int,object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     int64
# dtypes: int64(10), object(3)
# memory usage: 3.9+ KB

# %%
df.describe()
# Viewing the descriptive statistics of the data like mean, std deviation, min and max values present in the dataset
# Out:
#              sno        active      positive         cured          death  \
# count  37.000000     37.000000  3.700000e+01  3.700000e+01      37.000000
# mean   19.000000    978.162162  2.330763e+06  2.301449e+06   28335.405405
# std    10.824355   3047.254014  7.109508e+06  7.019192e+06   87897.112531
# min     1.000000      0.000000  1.003900e+04  9.907000e+03       4.000000
# 25%    10.000000      9.000000  1.008870e+05  9.996300e+04    1165.000000
# 50%    19.000000     72.000000  7.242200e+05  7.162320e+05    7693.000000
# 75%    28.000000    424.000000  1.288272e+06  1.278980e+06   14730.000000
# max    37.000000  18096.000000  4.311911e+07  4.257682e+07  524201.000000
#
#          new_active  new_positive     new_cured      new_death  state_code
# count     37.000000  3.700000e+01  3.700000e+01      37.000000   37.000000
# mean     956.324324  2.330897e+06  2.301605e+06   28335.891892   18.324324
# std     2973.389088  7.109914e+06  7.019659e+06   87899.184775   11.212726
# min        0.000000  1.003900e+04  9.907000e+03       4.000000    0.000000
# 25%        8.000000  1.008870e+05  9.996300e+04    1165.000000    9.000000
# 50%       79.000000  7.242200e+05  7.162320e+05    7693.000000   18.000000
# 75%      424.000000  1.288290e+06  1.278980e+06   14730.000000   28.000000
# max    17692.000000  4.312160e+07  4.257969e+07  524214.000000   37.000000

# %%
df.keys()
# Displaying all the column names present in data
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.columns
# Different code but same purpose as above that is displaying all column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.nunique()
# The nunique() function is used to count distinct observations over requested axis. It returns Series with number of distinct observations.
# Out:
# sno                 37
# state_name          37
# active              35
# positive            37
# cured               37
# death               37
# new_active          34
# new_positive        37
# new_cured           37
# new_death           37
# death_reconsille     2
# total                5
# state_code          37
# dtype: int64

# %%
df.tail()
# As we can see there is an extra row in the end that may be the total of that column
# Out:
#     sno     state_name  active  positive     cured   death  new_active  \
# 32   33        Tripura       1    100887     99963     923           1
# 33   34    Uttarakhand     477    437674    429504    7693         497
# 34   35  Uttar Pradesh    1278   2077406   2052615   23513        1174
# 35   36    West Bengal     407   2018763   1997153   21203         421
# 36   37                  18096  43119112  42576815  524201       17692
#
#     new_positive  new_cured  new_death death_reconsille total  state_code
# 32        100887      99963        923                                 16
# 33        437698     429508       7693                                  5
# 34       2077564    2052877      23513                                  9
# 35       2018820    1997196      21203                                 19
# 36      43121599   42579693     524214                8    13           0

# %%
df=df.iloc[:36]
# we apply the iloc function and select all rows except the last row

# %%
df
# This is the dataset that we are to work on
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     1               Andaman and Nicobar Islands       3     10039     9907
# 1     2                            Andhra Pradesh      72   2319797  2304995
# 2     3                         Arunachal Pradesh       4     64503    64203
# 3     4                                     Assam       2    724220   716232
# 4     5                                     Bihar      49    830653   818348
# 5     6                                Chandigarh      84     92208    90959
# 6     7                              Chhattisgarh      28   1152333  1138271
# 7     8  Dadra and Nagar Haveli and Daman and Diu       0     11441    11437
# 8     9                                     Delhi    4341   1899072  1868543
# 9    10                                       Goa      67    245548   241649
# 10   11                                   Gujarat     211   1224657  1213502
# 11   12                                   Haryana    1935    998552   985996
# 12   13                          Himachal Pradesh      69    284926   280721
# 13   14                         Jammu and Kashmir      55    454131   449325
# 14   15                                 Jharkhand      38    435289   429933
# 15   16                                 Karnataka    1861   3949446  3907480
# 16   17                                 Kerala***    3323   6546235  6473557
# 17   18                                    Ladakh       9     28256    28019
# 18   19                               Lakshadweep       0     11402    11350
# 19   20                            Madhya Pradesh     232   1041867  1030900
# 20   21                               Maharashtra    1455   7880337  7731029
# 21   22                                   Manipur       8    137230   135102
# 22   23                                 Meghalaya      13     93819    92213
# 23   24                                   Mizoram     260    227962   227005
# 24   25                                  Nagaland       1     35492    34731
# 25   26                                    Odisha     166   1288272  1278980
# 26   27                                Puducherry      12    165806   163832
# 27   28                                    Punjab     170    760028   742107
# 28   29                                 Rajasthan     616   1284618  1274448
# 29   30                                    Sikkim       7     39161    38702
# 30   31                                Tamil Nadu     424   3454556  3416107
# 31   32                                 Telangana     418    792526   787997
# 32   33                                   Tripura       1    100887    99963
# 33   34                               Uttarakhand     477    437674   429504
# 34   35                             Uttar Pradesh    1278   2077406  2052615
# 35   36                               West Bengal     407   2018763  1997153
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129           3         10039       9907        129
# 1    14730          79       2319814    2305005      14730
# 2      296           4         64503      64203        296
# 3     7986           2        724220     716232       7986
# 4    12256          38        830659     818365      12256
# 5     1165          90         92226      90971       1165
# 6    14034          28       1152334    1138272      14034
# 7        4           0         11441      11437          4
# 8    26188        3936       1899745    1869617      26192
# 9     3832          77        245562     241653       3832
# 10   10944         218       1224688    1213526      10944
# 11   10621        1952        998895     986322      10621
# 12    4136          78        284938     280724       4136
# 13    4751          58        454139     449330       4751
# 14    5318          34        435293     429941       5318
# 15   40105        1868       3949549    3907576      40105
# 16   69363        3393       6546758    6474002      69363                8
# 17     228           8         28256      28020        228
# 18      52           0         11402      11350         52
# 19   10735         244       1041903    1030924      10735
# 20  147853        1439       7880585    7731292     147854
# 21    2120           8        137230     135102       2120
# 22    1593          13         93820      92214       1593
# 23     697         269        227992     227026        697
# 24     760           2         35493      34731        760
# 25    9126         184       1288290    1278980       9126
# 26    1962          12        165809     163835       1962
# 27   17751         165        760051     742135      17751
# 28    9554         558       1284673    1274561       9554
# 29     452           7         39161      38702        452
# 30   38025         408       3454591    3416158      38025
# 31    4111         424        792571     788036       4111
# 32     923           1        100887      99963        923
# 33    7693         497        437698     429508       7693
# 34   23513        1174       2077564    2052877      23513
# 35   21203         421       2018820    1997196      21203
#
#    total  state_code
# 0                 35
# 1                 28
# 2                 12
# 3                 18
# 4                 10
# 5                  4
# 6                 22
# 7                 26
# 8      4           7
# 9                 30
# 10                24
# 11                 6
# 12                 2
# 13                 1
# 14                20
# 15                29
# 16     8          32
# 17                37
# 18                31
# 19                23
# 20     1          27
# 21                14
# 22                17
# 23                15
# 24                13
# 25                21
# 26                34
# 27                 3
# 28                 8
# 29                11
# 30                33
# 31                36
# 32                16
# 33                 5
# 34                 9
# 35                19

# %%
df['active'].sum(axis = 0) 
# The total number of active cases in India is:
# Out:
# 18096

# %%
df['positive'].sum(axis = 0) 
# The total number of positive cases in India are:
# Out:
# 43119112

# %%
df['cured'].sum(axis = 0)
# The total number of cured cases in India is:
# Out:
# 42576815

# %%
df['death'].sum(axis = 0)
# The total number of deaths in India are:
# Out:
# 524209

# %%
df['new_active'].sum(axis = 0)
# The total number of new active cases are:
# Out:
# 17692

# %%
df['new_positive'].sum(axis = 0)
# The total number of new positive cases are:
# Out:
# 43121599

# %%
df['new_cured'].sum(axis = 0)
# The total number of new cured cases are:
# Out:
# 42579693

# %%
df['new_death'].sum(axis = 0)
# The total number of new death cases are:
# Out:
# 524214

# %% [markdown]
# ### Data Visualization

# %%
sns.pairplot(data=df)
# plotting scatter plots of all data using pairplot

# %%
cases_df=df.sum()
# Storing total cases in cases_df

# %%
cases_df
# Subset of original dataset
# Out:
# sno                                                               666
# state_name          Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                          18096
# positive                                                     43119112
# cured                                                        42576815
# death                                                          524209
# new_active                                                      17692
# new_positive                                                 43121599
# new_cured                                                    42579693
# new_death                                                      524214
# death_reconsille                                                    8
# total                                                             481
# state_code                                                        678
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)
# Dropping unnecessary columns

# %%
cases_df
# Name of case types and their total number
# Out:
# active                 18096
# positive            43119112
# cured               42576815
# death                 524209
# new_active             17692
# new_positive        43121599
# new_cured           42579693
# new_death             524214
# death_reconsille           8
# total                    481
# dtype: object

# %%
my_data = [222526,10466595,10092909,151160]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [216558,10479179,10111294,151327]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [222526,10466595,10092909,151160,216558,10479179,10111294,151327]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
plt.rcParams['figure.figsize']=(13,8)
# giving figure size

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their active level of cases.
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their death cases.
# Maharashtra has a higher death cases compared to other states

# %%
df.columns
# Displaying column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);
# The below visualization shows us that high number of positive cases can be seen in Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);
# The visualization below shows us that high number of people have cured in the state of Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);
# The below visualization shows us that high number of deaths taking place in the state of Maharashtra followed by Tamilnadu and karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);
# The following visualization shows us the total number of new cases and kerela has the high number of new active cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);
# The following visualization shows us the total number of new positive cases and Maharashtra has the high number of new positive cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);
# The following visualization shows us the total number of new cured cases and Maharashtra has the high number of new cured cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);
# Maharashtra has the highest new death rates in India followed by Karnataka

# %%
df.columns
# column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)
# we have dropped columns like sno and statecode
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head(5)
# This is the resulting data
# Out:
#                     state_name  active  positive    cured  death  new_active  \
# 0  Andaman and Nicobar Islands       3     10039     9907    129           3
# 1               Andhra Pradesh      72   2319797  2304995  14730          79
# 2            Arunachal Pradesh       4     64503    64203    296           4
# 3                        Assam       2    724220   716232   7986           2
# 4                        Bihar      49    830653   818348  12256          38
#
#    new_positive  new_cured  new_death death_reconsille total
# 0         10039       9907        129
# 1       2319814    2305005      14730
# 2         64503      64203        296
# 3        724220     716232       7986
# 4        830659     818365      12256

# %%
df=df.set_index('state_name')
# Setting index as statename

# %%
df.head(5)
# Out:
#                              active  positive    cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands       3     10039     9907    129           3
# Andhra Pradesh                   72   2319797  2304995  14730          79
# Arunachal Pradesh                 4     64503    64203    296           4
# Assam                             2    724220   716232   7986           2
# Bihar                            49    830653   818348  12256          38
#
#                              new_positive  new_cured  new_death  \
# state_name
# Andaman and Nicobar Islands         10039       9907        129
# Andhra Pradesh                    2319814    2305005      14730
# Arunachal Pradesh                   64503      64203        296
# Assam                              724220     716232       7986
# Bihar                              830659     818365      12256
#
#                             death_reconsille total
# state_name
# Andaman and Nicobar Islands
# Andhra Pradesh
# Arunachal Pradesh
# Assam
# Bihar

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Stacked bar plot
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# bar plot for cured and death
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# bar plot for positive cases and death rate
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# barplot for death cases and cured cases
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
# Out:
# <AxesSubplot:ylabel='state_name'>
